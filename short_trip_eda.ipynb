# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('less_one_minute.csv')
data
# Out:
#                  ride_id  rideable_type               started_at  \
# 0       CEB3A25A22460197    docked_bike      2020-01-27 09:47:24
# 1       6DA9C3AEFF835497    docked_bike      2020-01-06 12:19:10
# 2       950D58DAF72AF908    docked_bike      2020-01-30 06:56:26
# 3       89D3D51310A2D7ED    docked_bike      2020-01-08 08:29:53
# 4       8681DB6781B16DCD    docked_bike      2020-01-09 18:36:53
# ...                  ...            ...                      ...
# 665839  85A353FD7022AB3E  electric_bike  2025-02-06 12:11:27.699
# 665840  525E8A49F5011F70  electric_bike  2025-02-04 16:02:47.062
# 665841  8F6094C592074639   classic_bike  2025-02-10 08:41:00.478
# 665842  D196C36B2F17CF9B  electric_bike  2025-02-28 21:33:27.943
# 665843  827751FDD842E23B   classic_bike  2025-02-26 15:44:42.111
#
#                        ended_at                   start_station_name  \
# 0           2020-01-27 09:47:31            LaSalle St & Jackson Blvd
# ...

# %%
data['time'].hist(color='skyblue', grid=False)
plt.title('Распределение времени коротких поездок')
plt.xlabel('Время поездки в мин.')
plt.ylabel('Количество')
plt.show()

# %%
df['is_loop'] = data['start_station_id'] == data['end_station_id']

# %%
df['is_loop'].sum() / len(df)
# Out:
# np.float64(0.5191891794474381)

# %%
df_bad = df[df['is_loop'] == 1]

# %%
df_bad
# Out:
#                  ride_id  rideable_type               started_at  \
# 0       CEB3A25A22460197    docked_bike      2020-01-27 09:47:24
# 2       950D58DAF72AF908    docked_bike      2020-01-30 06:56:26
# 3       89D3D51310A2D7ED    docked_bike      2020-01-08 08:29:53
# 4       8681DB6781B16DCD    docked_bike      2020-01-09 18:36:53
# 5       CBEFEF554E477BDC    docked_bike      2020-01-28 18:58:40
# ...                  ...            ...                      ...
# 665838  F7CFBCE7B2D4973A  electric_bike  2025-02-24 13:20:55.887
# 665839  85A353FD7022AB3E  electric_bike  2025-02-06 12:11:27.699
# 665840  525E8A49F5011F70  electric_bike  2025-02-04 16:02:47.062
# 665841  8F6094C592074639   classic_bike  2025-02-10 08:41:00.478
# 665842  D196C36B2F17CF9B  electric_bike  2025-02-28 21:33:27.943
#
#                        ended_at               start_station_name  \
# 0           2020-01-27 09:47:31        LaSalle St & Jackson Blvd
# ...

# %%
df_bad['time'].hist(color='skyblue', grid=False)
plt.title('Распределение времени плохих поездок')
plt.xlabel('Время поездки в мин.')
plt.ylabel('Количество')
plt.show()

# %%
data[data['is_loop'] == 0]['time'].hist(color='skyblue', grid=False)
plt.title('Распределение времени коротких не плохих поездок')
plt.xlabel('Время поездки в мин.')
plt.ylabel('Количество')
plt.show()

# %%
plt.figure(figsize=(8, 8))
sns.scatterplot(x='start_lng', y='start_lat', data=df_bad, alpha=0.5)
plt.title('Карта станций отправления для плохих поездок')
plt.xlabel('Долгота')
plt.ylabel('Широта')
plt.show()

# %%
data['started_at'] = pd.to_datetime(data['started_at'], format='mixed')

# %%
data_hour['hour_st'] = data['started_at'].dt.hour
data_hour
# Out:
#                  ride_id  rideable_type              started_at  \
# 0       CEB3A25A22460197    docked_bike 2020-01-27 09:47:24.000
# 1       6DA9C3AEFF835497    docked_bike 2020-01-06 12:19:10.000
# 2       950D58DAF72AF908    docked_bike 2020-01-30 06:56:26.000
# 3       89D3D51310A2D7ED    docked_bike 2020-01-08 08:29:53.000
# 4       8681DB6781B16DCD    docked_bike 2020-01-09 18:36:53.000
# ...                  ...            ...                     ...
# 665839  85A353FD7022AB3E  electric_bike 2025-02-06 12:11:27.699
# 665840  525E8A49F5011F70  electric_bike 2025-02-04 16:02:47.062
# 665841  8F6094C592074639   classic_bike 2025-02-10 08:41:00.478
# 665842  D196C36B2F17CF9B  electric_bike 2025-02-28 21:33:27.943
# 665843  827751FDD842E23B   classic_bike 2025-02-26 15:44:42.111
#
#                        ended_at                   start_station_name  \
# 0           2020-01-27 09:47:31            LaSalle St & Jackson Blvd
# ...

# %%
data_month['month_st'] = data_hour['started_at'].dt.month
data_month
# Out:
#                  ride_id  rideable_type              started_at  \
# 0       CEB3A25A22460197    docked_bike 2020-01-27 09:47:24.000
# 1       6DA9C3AEFF835497    docked_bike 2020-01-06 12:19:10.000
# 2       950D58DAF72AF908    docked_bike 2020-01-30 06:56:26.000
# 3       89D3D51310A2D7ED    docked_bike 2020-01-08 08:29:53.000
# 4       8681DB6781B16DCD    docked_bike 2020-01-09 18:36:53.000
# ...                  ...            ...                     ...
# 665839  85A353FD7022AB3E  electric_bike 2025-02-06 12:11:27.699
# 665840  525E8A49F5011F70  electric_bike 2025-02-04 16:02:47.062
# 665841  8F6094C592074639   classic_bike 2025-02-10 08:41:00.478
# 665842  D196C36B2F17CF9B  electric_bike 2025-02-28 21:33:27.943
# 665843  827751FDD842E23B   classic_bike 2025-02-26 15:44:42.111
#
#                        ended_at                   start_station_name  \
# 0           2020-01-27 09:47:31            LaSalle St & Jackson Blvd
# ...

# %%
df_bad['started_at'] = pd.to_datetime(df_bad['started_at'], format='mixed')

# %%
df_bad_hour['hour_st'] = df_bad['started_at'].dt.hour
df_bad_hour

# %%
df_bad_month['month_st'] = df_bad_hour['started_at'].dt.month
df_bad_month

# %%
df_bad_hour.groupby('hour_st').size().plot(color='skyblue')
plt.title('Распределение плохих поездок по часам')
plt.xlabel('Час')
plt.ylabel('Количество')
plt.show()

# %%
df_bad_month.groupby('month_st').size().plot(color='skyblue')
plt.title('Распределение плохих поездок по месяцам')
plt.xlabel('Месяц')
plt.ylabel('Количество')
plt.show()

# %%
plt.figure(figsize=(8, 5))
df_bad.groupby('member_casual').size().plot(kind='bar', color='skyblue')
plt.title('Количество плохих поездок по типу пользователя')
plt.xlabel('Тип')
plt.ylabel('Количество')
plt.show()

# %%
data_month.groupby('member_casual').size()
# Out:
# member_casual
# casual    262329
# member    403515
# dtype: int64

# %%
cnt = df_bad_month.groupby('member_casual').size()
cnt['casual'] /= (9601972 + 262329)
cnt['member'] /= (15699975 + 403515)
cnt
# Out:
# C:\Users\Vadim Prokofev\AppData\Local\Temp\ipykernel_27680\517835285.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.013081818975313101' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   cnt['casual'] /= (9601972 + 262329)
# member_casual
# casual    0.013082
# member    0.013454
# dtype: float64

# %%
cnt['casual'] *= 100
cnt['member'] *= 100

# %%
plt.figure(figsize=(8, 5))
cnt.plot(kind='bar', color='skyblue')
plt.title('Процент плохих поездок от всех по типу пользователя')
plt.xlabel('Тип пользователя')
plt.ylabel('Процент плохих поездок')
plt.show()

# %%
plt.figure(figsize=(8, 5))
df_bad_month.groupby('rideable_type').size().plot(kind='bar', color='skyblue')
plt.title('Количество плохих поездок по типу велосипеда')
plt.xlabel('Тип велосипеда')
plt.ylabel('Количество плохих поездок')
plt.show()

# %%
data.groupby('rideable_type').size()
# Out:
# rideable_type
# classic_bike        181597
# docked_bike          50904
# electric_bike       425214
# electric_scooter      8129
# dtype: int64

# %%
cnt = df_bad_month.groupby('rideable_type').size()
cnt['classic_bike'] = (cnt['classic_bike'] / (181597 + 10980912)) * 100
cnt['docked_bike'] = (cnt['docked_bike'] / (50904 + 3203029)) * 100
cnt['electric_bike'] = (cnt['electric_bike'] / (425214 + 10982444)) * 100
cnt['electric_scooter'] = (cnt['electric_scooter'] / (8129 + 135562)) * 100
# Out:
# C:\Users\Vadim Prokofev\AppData\Local\Temp\ipykernel_13528\4235526084.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.36806160693801' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   cnt['classic_bike'] = (cnt['classic_bike'] / (181597 + 10980912)) * 100

# %%
plt.figure(figsize=(8, 5))
cnt.plot(kind='bar', color='skyblue')
plt.title('Процент плохих поездок от всех по типу велосипеда')
plt.xlabel('Тип велосипеда')
plt.ylabel('Процент плохих поездок')
plt.show()

# %%
data_hour.groupby('hour_st').size().plot(color='skyblue')
plt.title('Распределение коротких поездок по часам суток')
plt.xlabel('Час суток')
plt.ylabel('Количество')
plt.show()

# %%
data_month.groupby('month_st').size().plot(color='skyblue')
plt.title('Распределение коротких поездок по месяцам')
plt.xlabel('Месяц')
plt.ylabel('Количество')
plt.show()

# %%
data_weekday['weekday'] = data_month['started_at'].dt.weekday

# %%
data_weekday
# Out:
#                  ride_id  rideable_type              started_at  \
# 0       CEB3A25A22460197    docked_bike 2020-01-27 09:47:24.000
# 1       6DA9C3AEFF835497    docked_bike 2020-01-06 12:19:10.000
# 2       950D58DAF72AF908    docked_bike 2020-01-30 06:56:26.000
# 3       89D3D51310A2D7ED    docked_bike 2020-01-08 08:29:53.000
# 4       8681DB6781B16DCD    docked_bike 2020-01-09 18:36:53.000
# ...                  ...            ...                     ...
# 665839  85A353FD7022AB3E  electric_bike 2025-02-06 12:11:27.699
# 665840  525E8A49F5011F70  electric_bike 2025-02-04 16:02:47.062
# 665841  8F6094C592074639   classic_bike 2025-02-10 08:41:00.478
# 665842  D196C36B2F17CF9B  electric_bike 2025-02-28 21:33:27.943
# 665843  827751FDD842E23B   classic_bike 2025-02-26 15:44:42.111
#
#                        ended_at                   start_station_name  \
# 0           2020-01-27 09:47:31            LaSalle St & Jackson Blvd
# ...

# %%
data_weekday.groupby('weekday').size().plot(color='skyblue')
plt.title('Распределение коротких поездок по дням недели')
plt.xlabel('День недели')
plt.ylabel('Количество')
plt.show()

# %%
plt.figure(figsize=(8, 5))
data_weekday.groupby('member_casual').size().plot(kind='bar', color='skyblue')
plt.title('Количество коротких поездок по типу пользователя')
plt.xlabel('Тип')
plt.ylabel('Количество')
plt.show()

# %%
cnt = data.groupby('member_casual').size()
cnt['casual'] /= (9601972 + 262329)
cnt['member'] /= (15699975 + 403515)
cnt
# Out:
# C:\Users\Vadim Prokofev\AppData\Local\Temp\ipykernel_13528\2629722385.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.026593774865548' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   cnt['casual'] /= (9601972 + 262329)
# member_casual
# casual    0.026594
# member    0.025058
# dtype: float64

# %%
plt.figure(figsize=(8, 5))
cnt.plot(kind='bar', color='skyblue')
plt.title('Процент коротких поездок от всех по типу пользователя')
plt.xlabel('Тип пользователя')
plt.ylabel('Процент коротких поездок')
plt.show()

# %%
data_weekday[data_weekday['member_casual'] == 'member'].groupby('weekday').size().plot(color='skyblue')
plt.title('Распределение коротких поездок для member по дням недели')
plt.xlabel('День недели')
plt.ylabel('Количество')
plt.show()

# %%
data_weekday[data_weekday['member_casual'] == 'casual'].groupby('weekday').size().plot(color='skyblue')
plt.title('Распределение коротких поездок для casual по дням недели')
plt.xlabel('День недели')
plt.ylabel('Количество')
plt.show()

# %%
data_hour[data_hour['member_casual'] == 'member'].groupby('hour_st').size().plot(color='skyblue')
plt.title('Распределение коротких поездок для member по часам суток')
plt.xlabel('Час суток')
plt.ylabel('Количество')
plt.show()

# %%
data_hour[data_hour['member_casual'] == 'casual'].groupby('hour_st').size().plot(color='skyblue')
plt.title('Распределение коротких поездок для casual по часам суток')
plt.xlabel('Час суток')
plt.ylabel('Количество')
plt.show()

# %%
plt.figure(figsize=(8, 5))
data.groupby('rideable_type').size().plot(kind='bar', color='skyblue')
plt.title('Количество коротких поездок по типу велосипеда')
plt.xlabel('Тип велосипеда')
plt.ylabel('Количество')
plt.show()

# %%
cnt = data.groupby('rideable_type').size()
cnt['classic_bike'] = (cnt['classic_bike'] / (181597 + 10980912)) * 100
cnt['docked_bike'] = (cnt['docked_bike'] / (50904 + 3203029)) * 100
cnt['electric_bike'] = (cnt['electric_bike'] / (425214 + 10982444)) * 100
cnt['electric_scooter'] = (cnt['electric_scooter'] / (8129 + 135562)) * 100
# Out:
# C:\Users\Vadim Prokofev\AppData\Local\Temp\ipykernel_13528\1725185226.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.6268475125081647' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   cnt['classic_bike'] = (cnt['classic_bike'] / (181597 + 10980912)) * 100

# %%
plt.figure(figsize=(8, 5))
cnt.plot(kind='bar', color='skyblue')
plt.title('Процент коротких поездок от всех по типу велосипеда')
plt.xlabel('Тип велосипеда')
plt.ylabel('Процент коротких поездок')
plt.show()

# %%
data_weekday[data_weekday['rideable_type'] == 'classic_bike'].groupby('weekday').size().plot(color='skyblue')
plt.title('Распределение коротких поездок для classic bike по дням недели')
plt.xlabel('День недели')
plt.ylabel('Количество')
plt.show()

# %%
data_weekday[data_weekday['rideable_type'] == 'docked_bike'].groupby('weekday').size().plot(color='skyblue')
plt.title('Распределение коротких поездок для docked bike по дням недели')
plt.xlabel('День недели')
plt.ylabel('Количество')
plt.show()

# %%
data_weekday[data_weekday['rideable_type'] == 'electric_bike'].groupby('weekday').size().plot(color='skyblue')
plt.title('Распределение коротких поездок для electric bike по дням недели')
plt.xlabel('День недели')
plt.ylabel('Количество')
plt.show()

# %%
data_weekday[data_weekday['rideable_type'] == 'electric_scooter'].groupby('weekday').size().plot(color='skyblue')
plt.title('Распределение коротких поездок для electric scooter по дням недели')
plt.xlabel('День недели')
plt.ylabel('Количество')
plt.show()

# %%
data_weekday[data_weekday['rideable_type'] == 'classic_bike'].groupby('hour_st').size().plot(color='skyblue')
plt.title('Распределение коротких поездок для classic bike по часам суток')
plt.xlabel('Час суток')
plt.ylabel('Количество')
plt.show()

# %%
data_hour[data_hour['rideable_type'] == 'docked_bike'].groupby('hour_st').size().plot(color='skyblue')
plt.title('Распределение коротких поездок для docked bike по часам суток')
plt.xlabel('Час суток')
plt.ylabel('Количество')
plt.show()

# %%
data_hour[data_hour['rideable_type'] == 'electric_bike'].groupby('hour_st').size().plot(color='skyblue')
plt.title('Распределение коротких поездок для electric bike по часам суток')
plt.xlabel('Час суток')
plt.ylabel('Количество')
plt.show()

# %%
data_hour[data_hour['rideable_type'] == 'electric_scooter'].groupby('hour_st').size().plot(color='skyblue')
plt.title('Распределение коротких поездок для electric scooter по часам суток')
plt.xlabel('Час суток')
plt.ylabel('Количество')
plt.axvline(x=8, label='8')
plt.axvline(x=17, label='17', color='red')
plt.legend()
plt.show()

# %%
data_weekday[(data_weekday['rideable_type'] == 'electric_scooter') & (data_weekday['member_casual'] == 'member')].groupby('weekday').size().plot(color='skyblue')
plt.title('Распределение коротких поездок для electric scooter of members по дням недели')
plt.xlabel('День недели')
plt.ylabel('Количество')
plt.show()

# %%
data_weekday[(data_weekday['rideable_type'] == 'electric_scooter') & (data_weekday['member_casual'] == 'casual')].groupby('weekday').size().plot(color='skyblue')
plt.title('Распределение коротких поездок для electric scooter of casual по дням недели')
plt.xlabel('День недели')
plt.ylabel('Количество')
plt.show()

# %%
plt.figure(figsize=(8, 5))
data[data['member_casual'] == 'member'].groupby('rideable_type').size().plot(kind='bar', color='skyblue')
plt.title('Количество коротких поездок по типу велосипеда для member')
plt.xlabel('Тип велосипеда')
plt.ylabel('Количество')
plt.show()

# %%
plt.figure(figsize=(8, 5))
data[data['member_casual'] == 'casual'].groupby('rideable_type').size().plot(kind='bar', color='skyblue')
plt.title('Количество коротких поездок по типу велосипеда для casual')
plt.xlabel('Тип велосипеда')
plt.ylabel('Количество')
plt.show()

# %%
member_data = data_weekday[(data_weekday['rideable_type'] == 'electric_scooter') & (data_weekday['member_casual'] == 'member')].groupby('weekday').size()
casual_data = data_weekday[(data_weekday['rideable_type'] == 'electric_scooter') & (data_weekday['member_casual'] == 'casual')].groupby('weekday').size()
plt.figure(figsize=(10, 6))
plt.plot(member_data.index, member_data.values, label='Member', color='skyblue', marker='o')
plt.plot(casual_data.index, casual_data.values, label='Casual', color='orange', marker='x')
plt.title('Распределение коротких поездок для electric scooter по дням недели')
plt.xlabel('День недели')
plt.ylabel('Количество')
plt.legend()
plt.show()

# %%
member_data = data_weekday[(data_weekday['rideable_type'] == 'electric_bike') & (data_weekday['member_casual'] == 'member')].groupby('weekday').size()
casual_data = data_weekday[(data_weekday['rideable_type'] == 'electric_bike') & (data_weekday['member_casual'] == 'casual')].groupby('weekday').size()
plt.figure(figsize=(10, 6))
plt.plot(member_data.index, member_data.values, label='Member', color='skyblue', marker='o')
plt.plot(casual_data.index, casual_data.values, label='Casual', color='orange', marker='x')
plt.title('Распределение коротких поездок для electric bike по дням недели')
plt.xlabel('День недели')
plt.ylabel('Количество')
plt.legend()
plt.show()

# %%
member_data = data_weekday[(data_weekday['rideable_type'] == 'classic_bike') & (data_weekday['member_casual'] == 'member')].groupby('weekday').size()
casual_data = data_weekday[(data_weekday['rideable_type'] == 'classic_bike') & (data_weekday['member_casual'] == 'casual')].groupby('weekday').size()
plt.figure(figsize=(10, 6))
plt.plot(member_data.index, member_data.values, label='Member', color='skyblue', marker='o')
plt.plot(casual_data.index, casual_data.values, label='Casual', color='orange', marker='x')
plt.title('Распределение коротких поездок для classic bike по дням недели')
plt.xlabel('День недели')
plt.ylabel('Количество')
plt.legend()
plt.show()

# %%
member_data = data_weekday[(data_weekday['rideable_type'] == 'docked_bike') & (data_weekday['member_casual'] == 'member')].groupby('weekday').size()
casual_data = data_weekday[(data_weekday['rideable_type'] == 'docked_bike') & (data_weekday['member_casual'] == 'casual')].groupby('weekday').size()
plt.figure(figsize=(10, 6))
plt.plot(member_data.index, member_data.values, label='Member', color='skyblue', marker='o')
plt.plot(casual_data.index, casual_data.values, label='Casual', color='orange', marker='x')
plt.title('Распределение коротких поездок для docked bike по дням недели')
plt.xlabel('День недели')
plt.ylabel('Количество')
plt.legend()
plt.show()

# %%
member_classic = data_weekday[(data_weekday['rideable_type'] == 'classic_bike') & (data_weekday['member_casual'] == 'member')].groupby('weekday').size()
member_docked = data_weekday[(data_weekday['rideable_type'] == 'docked_bike') & (data_weekday['member_casual'] == 'member')].groupby('weekday').size()
member_electric = data_weekday[(data_weekday['rideable_type'] == 'electric_bike') & (data_weekday['member_casual'] == 'member')].groupby('weekday').size()
member_elec_sc = data_weekday[(data_weekday['rideable_type'] == 'electric_scooter') & (data_weekday['member_casual'] == 'member')].groupby('weekday').size()

plt.figure(figsize=(10, 6))
plt.plot(member_classic.index, member_classic.values, label='Classic', color='skyblue', marker='o')
plt.plot(member_docked.index, member_docked.values, label='Docked', color='orange', marker='x')
plt.plot(member_electric.index, member_electric.values, label='Electric', color='red', marker='x')
plt.plot(member_elec_sc.index, member_elec_sc.values, label='Electric scooter', color='green', marker='x')

plt.title('Распределение коротких поездок для member по дням недели')
plt.xlabel('День недели')
plt.ylabel('Количество')
plt.legend()
plt.show()

# %%
member_classic = data_weekday[(data_weekday['rideable_type'] == 'classic_bike') & (data_weekday['member_casual'] == 'member')].groupby('weekday').size()
member_docked = data_weekday[(data_weekday['rideable_type'] == 'docked_bike') & (data_weekday['member_casual'] == 'member')].groupby('weekday').size()
member_electric = data_weekday[(data_weekday['rideable_type'] == 'electric_bike') & (data_weekday['member_casual'] == 'member')].groupby('weekday').size()
member_elec_sc = data_weekday[(data_weekday['rideable_type'] == 'electric_scooter') & (data_weekday['member_casual'] == 'member')].groupby('weekday').size()

plt.figure(figsize=(10, 6))
plt.plot(member_classic.index, member_classic.values, label='Classic', color='skyblue', marker='o')
plt.plot(member_docked.index, member_docked.values, label='Docked', color='orange', marker='x')
#plt.plot(member_electric.index, member_electric.values, label='Electric', color='red', marker='x')
plt.plot(member_elec_sc.index, member_elec_sc.values, label='Electric scooter', color='green', marker='x')

plt.title('Распределение коротких поездок для member по дням недели')
plt.xlabel('День недели')
plt.ylabel('Количество')
plt.legend()
plt.show()

# %%
member_classic = data_weekday[(data_weekday['rideable_type'] == 'classic_bike') & (data_weekday['member_casual'] == 'member')].groupby('weekday').size()
member_docked = data_weekday[(data_weekday['rideable_type'] == 'docked_bike') & (data_weekday['member_casual'] == 'member')].groupby('weekday').size()
member_electric = data_weekday[(data_weekday['rideable_type'] == 'electric_bike') & (data_weekday['member_casual'] == 'member')].groupby('weekday').size()
member_elec_sc = data_weekday[(data_weekday['rideable_type'] == 'electric_scooter') & (data_weekday['member_casual'] == 'member')].groupby('weekday').size()

plt.figure(figsize=(10, 6))
#plt.plot(member_classic.index, member_classic.values, label='Classic', color='skyblue', marker='o')
plt.plot(member_docked.index, member_docked.values, label='Docked', color='orange', marker='x')
#plt.plot(member_electric.index, member_electric.values, label='Electric', color='red', marker='x')
plt.plot(member_elec_sc.index, member_elec_sc.values, label='Electric scooter', color='green', marker='x')

plt.title('Распределение коротких поездок для member по дням недели')
plt.xlabel('День недели')
plt.ylabel('Количество')
plt.legend()
plt.show()
